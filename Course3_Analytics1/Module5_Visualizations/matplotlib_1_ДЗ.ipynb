# %% [markdown]
# # Основы визуализации данных с помощью Matplotlib
#
# ## Домашнее задание
#
# ### Цель домашнего задания
#
# Отработать навык визуализации данных с помощью простых графиков matplotlib. Научиться использовать визуализацию данных для проверки гипотез и валидации данных.
#
# ### Описание домашнего задания и формат сдачи
#
# Вам предстоит выполнить задачи по визуализации данных. Для этого  впишите свой код в ячейки после комментария `### YOUR CODE HERE ###` и сохраните изменения, используя опцию *Save and Checkpoint* из вкладки меню *File* или кнопку *Save and Checkpoint* на панели инструментов. Итоговый файл в формате `.ipynb` (файл Jupyter Notebook) загрузите в личный кабинет и отправьте на проверку преподавателю.
#
# **Важно учесть:** У всех графиков обязательно должен присутствовать заголовок и подписи осей. Убедитесь, что все метки и подписи осей читаемы.
#
# #### Описание данных
#
# Для выполнения домашнего задания необходимо использовать датасет `vgsales.csv`, загрузка которого будет приведена ниже. Этот датасет содержит информацию о суммарных продажах видеоигр для игровых консолей. Описание признаков:
# * `Rank` – порядковый номер записи в датасете
# * `Name` – наименование игры
# * `Platform` – платформа, для которой выпущена игра (Nintendo, PlayStation, XBox и др.)
# * `Year` – год выпуска игры
# * `Genre` – жанр игры
# * `Publisher` – наименование компании-издателя игры
# * `NA_Sales` – объем продаж игры в Северной Америке, млн. копий
# * `EU_Sales` – объем продаж игры в Европе, млн. копий
# * `JP_Sales` – объем продаж игры в Японии, млн. копий
# * `Other_Sales` – объем продаж игры в остальных странах, млн. копий
# * `Global_Sales` – объем продаж игры по всему миру, млн. копий
#
# ### Критерии оценки
#
# **Зачет** – выполнены задачи 1-9, каждый график отформатирован и читаем
#
# **На доработку** – выполнены не все обязательные задачи или какой-либо из графиков не читаем или не подписан
#
# ### Рекомендации по выполнению
#
# * Библиотеки, необходимые для выполнения домашнего задания, перечислены в ячейке ниже.
# * Подсказка по работе с Jupyter: если перед графиком выводится слишком много текста, поставьте ';' в конце последней строки ячейки.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Загрузка данных

# %%
df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### Задача 1
#
# Постройте гистограмму распределения объема продаж всех игр в Японии.

# %%
jp_sales = df.JP_Sales
jp_sales
# Out:
# 0         3.77
# 1         6.81
# 2         3.79
# 3         3.28
# 4        10.22
#          ...
# 16593     0.00
# 16594     0.00
# 16595     0.00
# 16596     0.00
# 16597     0.00
# Name: JP_Sales, Length: 16598, dtype: float64

# %%
print(jp_sales.min())
print(jp_sales.max())
# Out:
# 0.0
# 10.22

# %%
bin_w = jp_sales.max() / 10
plt.hist(jp_sales, bins=10)
plt.xticks([i * bin_w for i in range(0, 11)])
plt.title('Распределение объема продаж всех игр в Японии')
plt.xlabel('# Проданных копий (млн)')
plt.ylabel('# Записей')
# Out:
# Text(0, 0.5, '# Записей')

# %% [markdown]
# ### Задача 2
#
# Постройте столбчатую диаграмму (barchart), показывающую сравнение общемирового объема продаж игры "Grand Theft Auto V" на разных платформах.

# %%
gta_sales = df[df['Name'] == 'Grand Theft Auto V'][['Platform', 'Global_Sales']]
gta_sales
# Out:
#      Platform  Global_Sales
# 16        PS3         21.40
# 23       X360         16.38
# 44        PS4         11.98
# 197      XOne          5.08
# 1896       PC          1.08

# %%
plt.bar(gta_sales.Platform, gta_sales.Global_Sales)
plt.title('Общемировой объем продаж игры “Grand Theft Auto V” на разных платформах')
plt.xlabel('Платформа')
plt.ylabel('# Проданных копий (млн)')
# Out:
# Text(0, 0.5, '$ Продаж')

# %% [markdown]
# ### Задача 3
#
# Постройте линейный график динамики суммарных общемировых продаж всех игр по годам.

# %%
global_sales = df.groupby('Year').sum().Global_Sales
global_sales
# Out:
# Year
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.16
# 1993.0     45.98
# 1994.0     79.17
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.47
# 1999.0    251.27
# 2000.0    201.56
# 2001.0    331.47
# 2002.0    395.52
# 2003.0    357.85
# 2004.0    419.31
# 2005.0    459.94
# 2006.0    521.04
# 2007.0    611.13
# 2008.0    678.90
# 2009.0    667.30
# 2010.0    600.45
# 2011.0    515.99
# 2012.0    363.54
# 2013.0    368.11
# 2014.0    337.05
# 2015.0    264.44
# 2016.0     70.93
# 2017.0      0.05
# 2020.0      0.29
# Name: Global_Sales, dtype: float64

# %%
plt.plot(global_sales)
plt.title('Динамика суммарных общемировых продаж всех игр по годам')
plt.xlabel('Год')
plt.ylabel('# Проданных копий (млн)')
# Out:
# Text(0, 0.5, '# Проданных копий (млн)')

# %% [markdown]
# ### Задача 4
#
# Постройте точечную диаграмму, показывающую существование зависимости продаж во всем мире от продаж в Северной Америке.

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
plt.scatter(df.Year, df.NA_Sales, c='red', label='North America')
plt.scatter(df.Year, df.Global_Sales, c='blue', label='Global')
plt.title('Зависимость продаж во всем мире от продаж в Северной Америке')
plt.xlabel('Год')
plt.ylabel('# Проданных копий (млн)')
plt.legend()

# %% [markdown]
# ### Задача 5
#
# Постройте круговую диаграмму процентного соотношения продаж игры "Super Mario Bros." на разных платформах во всем мире. Подпишите доли графика с точностью 1 знак после запятой.

# %%
mario_sales = df[df['Name'] == 'Super Mario Bros.'].groupby('Platform').sum().Global_Sales
mario_sales
# Out:
# Platform
# GB      5.07
# NES    40.24
# Name: Global_Sales, dtype: float64

# %%
plt.pie(mario_sales, labels=mario_sales.index, autopct='%1.1f%%')
plt.title('Продажи игры “Super Mario Bros.” на разных платформах во всем мире')
# Out:
# Text(0.5, 1.0, 'Продажи игры “Super Mario Bros.” на разных платформах во всем мире')

# %% [markdown]
# ### Задача 6
#
# Определите 5 издателей, имеющих наибольшие суммарные продажи во всём мире в 2013 году, и проиллюстрируйте величину их продаж на столбчатой диаграмме.

# %%
top_publishers = df[df['Year'] == 2013]\
    .groupby('Publisher')\
    .sum()\
    .Global_Sales\
    .sort_values(ascending=False)\
    .head(5)
top_publishers
# Out:
# Publisher
# Electronic Arts         52.92
# Nintendo                52.79
# Take-Two Interactive    52.41
# Activision              43.49
# Ubisoft                 27.39
# Name: Global_Sales, dtype: float64

# %%
plt.bar(top_publishers.index, top_publishers)
plt.xticks(rotation=45)
plt.title('5 издателей, имеющих наибольшие суммарные продажи во всём мире в 2013 году')
plt.xlabel('Название издателя')
plt.ylabel('# Проданных копий (млн)')
# Out:
# Text(0, 0.5, '# Проданных копий (млн)')

# %% [markdown]
# ### Задача 7
#
# Постройте гистограмму распределения величины общемировых продаж игр, выпущенных не издателем Nintendo, в период с 2000 по 2015 год включительно. Гистограмма для большей точности должна содержать 20 столбцов, отсечки на оси X должны соответствовать границам столбцов.

# %%
non_nintendo = df[(df['Publisher'] != 'Nintendo') & (df['Year'] >= 2000) & (df['Year'] <= 2015)][['Year', 'Global_Sales']]
non_nintendo.head()
# Out:
#       Year  Global_Sales
# 15  2010.0         21.82
# 16  2013.0         21.40
# 17  2004.0         20.81
# 23  2013.0         16.38
# 24  2002.0         16.15

# %%
bin_w = (non_nintendo.Global_Sales.max() - non_nintendo.Global_Sales.min()) / 20

plt.hist(non_nintendo.Global_Sales, bins=20)
plt.xticks([i * bin_w for i in range(21)], rotation=45)
plt.title('Распределение величин общемировых продаж игр, выпущенных не издателем Nintendo, в период с 2000 по 2015 год включительно')
plt.xlabel('# Проданных копий (млн)')
plt.ylabel('# Записей')
# Out:
# Text(0, 0.5, '# Записей')

# %% [markdown]
# ### Задача 8
#
# Постройте линейный график динамики суммарных мировых продаж игр жанра "Action" по годам.

# %%
action_sales = df[df['Genre'] == 'Action'].groupby('Year').sum().Global_Sales
action_sales
# Out:
# Year
# 1980.0      0.34
# 1981.0     14.84
# 1982.0      6.52
# 1983.0      2.86
# 1984.0      1.85
# 1985.0      3.52
# 1986.0     13.74
# 1987.0      1.12
# 1988.0      1.75
# 1989.0      4.64
# 1990.0      6.39
# 1991.0      6.76
# 1992.0      3.83
# 1993.0      1.81
# 1994.0      1.55
# 1995.0      3.57
# 1996.0     20.58
# 1997.0     27.58
# 1998.0     39.44
# 1999.0     27.78
# 2000.0     34.04
# 2001.0     59.39
# 2002.0     86.77
# 2003.0     67.93
# 2004.0     76.26
# 2005.0     85.69
# 2006.0     66.58
# 2007.0    106.50
# 2008.0    136.39
# 2009.0    139.36
# 2010.0    117.64
# 2011.0    118.96
# 2012.0    122.04
# 2013.0    125.22
# 2014.0     99.02
# 2015.0     70.70
# 2016.0     19.91
# 2017.0      0.01
# Name: Global_Sales, dtype: float64

# %%
plt.plot(action_sales)
plt.title('Динамика суммарных мировых продаж игр жанра “Action” по годам')
plt.xlabel('Год')
plt.ylabel('# Проданных копий (млн)')
# Out:
# Text(0, 0.5, '# Проданных копий (млн)')

# %% [markdown]
# ### Задача 9
#
# С помощью столбчатой диаграммы проиллюстрируйте объем продаж всех игр издателя "Microsoft Game Studios" в Северной Америке за все время в зависимости от жанра. Столбцы расположите по убыванию.

# %%
microsoft_sales = df[df['Publisher'] == 'Microsoft Game Studios']\
    .groupby('Genre')\
    .sum()\
    .NA_Sales\
    .sort_values(ascending=False)
microsoft_sales
# Out:
# Genre
# Shooter         64.65
# Misc            30.61
# Racing          16.83
# Role-Playing    12.79
# Sports           9.69
# Action           8.09
# Simulation       7.10
# Strategy         1.81
# Fighting         1.68
# Adventure        1.09
# Platform         0.94
# Puzzle           0.07
# Name: NA_Sales, dtype: float64

# %%
plt.bar(microsoft_sales.index, microsoft_sales)
plt.xticks(rotation=45)
plt.title('Объем продаж всех игр издателя “Microsoft Game Studios” в Северной Америке за все время в зависимости от жан')
plt.xlabel('Жанр')
plt.ylabel('# Проданных копий (млн)')
# Out:
# Text(0, 0.5, '# Проданных копий (млн)')

# %% [markdown]
# ## Дополнительные (необязательные) задачи
#
# ### Задача 10
#
# Одной из основных задач при анализе данных является проверка данных на корректность и отсутствие ошибок. В датасете "vgsales" одним из потенциальных источников ошибок является столбец с общемировыми продажами. По идее, значение общемировых продаж какой-либо игры должно равняться сумме продаж в Северной Америке, Европе, Японии и остальных странах, в противном случае мы получим ошибку в данных, которая может негативно повлиять на весь дальнейший процесс анализа.
#
# Причин возникновения такой ошибки может быть несколько. Давайте рассмотрим следующие причины:
# 1. Ошибка округления. В целом, такая ошибка достаточно часто встречается при переводе величин из одних единиц в другие (например, из тысяч копий в миллионы копий).
# 1. Ошибка вычислений. Такая ситуация требует более серьезного исследования, поскольку она может привести к недостоверным результатам анализа данных.
#
# Будем считать, что в записи имеется ошибка суммирования, если сумма продаж какой-либо игры в Северной Америке, Европе, Японии и остальных странах отличается от общемировых продаж более, чем на 0.01 млн копий.
#
# С помощью круговой диаграммы проиллюстрируйте процент записей в датасете, имеющих такую ошибку суммирования продаж.

# %%
import numpy as np

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
sum_of_sales = df.loc[:, 'NA_Sales':'Other_Sales'].sum(axis=1)
sum_of_sales.head()
# Out:
# 0    82.74
# 1    40.24
# 2    35.83
# 3    33.00
# 4    31.38
# dtype: float64

# %%
df['Is_Error'] = np.abs(sum_of_sales - df.Global_Sales) > 0.01
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Is_Error
# 0     41.49     29.02      3.77         8.46         82.74     False
# 1     29.08      3.58      6.81         0.77         40.24     False
# 2     15.85     12.88      3.79         3.31         35.82      True
# 3     15.75     11.01      3.28         2.96         33.00     False
# 4     11.27      8.89     10.22         1.00         31.37      True

# %%
error_counts = df.groupby('Is_Error').size()

# %%
plt.pie(error_counts, labels=['Correct', 'Error'], autopct='%1.1f%%', colors=['blue', 'red'])
plt.title('Соотношение записей в датасете, имеющих ошибку суммирования продаж')
# Out:
# Text(0.5, 1.0, 'Соотношение записей в датасете, имеющих ошибку суммирования продаж')
